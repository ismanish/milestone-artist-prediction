# %%
import os
import copy
import matplotlib.pyplot as plt
import torch
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader, random_split
from torchvision.datasets import ImageFolder
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torchvision import models
import sys
from collections import Counter
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import confusion_matrix
import seaborn as sns
from sklearn.model_selection import ParameterGrid
from torch.optim.lr_scheduler import ReduceLROnPlateau
import warnings
warnings.filterwarnings("ignore")

# %%
# Data Preparation
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# %%
dataset_path = './data/wikiart_sample/'
dataset = ImageFolder(root=dataset_path, transform=transform)

# %%
train_size = int(0.8 * len(dataset))
val_size = len(dataset) - train_size
train_dataset, val_dataset = random_split(dataset, [train_size, val_size])

# %%
class CustomResNet50(nn.Module):
    def __init__(self, dropout_rate=0.0, num_classes=27):
        super(CustomResNet50, self).__init__()
        self.resnet50_model = models.resnet50(pretrained=True)
        num_ftrs = self.resnet50_model.fc.in_features
        self.resnet50_model.fc = nn.Sequential(
            nn.Dropout(dropout_rate),
            nn.Linear(num_ftrs, num_classes)
        )

    def forward(self, x):
        return self.resnet50_model(x)

# %%
param_grid = {
    'batch_size': [16, 32],
    'lr': [0.0001, 0.001],
    'dropout_rate': [0.1, 0.5],
    'optimizer': ['Adam', 'RMSprop'],
    'weight_decay': [0, 0.01]
}

# %%
# Create Parameter grid
param_list = list(ParameterGrid(param_grid))

best_model = None
best_params = None
best_accuracy = 0.0

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
performance_dict = {}
for params in param_list:
    train_loader = DataLoader(train_dataset, batch_size=params['batch_size'], shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=params['batch_size'], shuffle=False)

    model = CustomResNet50(dropout_rate=params['dropout_rate'])
    model.to(device)

    if params['optimizer'] == 'Adam':
        optimizer = optim.Adam(model.parameters(), lr=params['lr'], weight_decay=params['weight_decay'])
    elif params['optimizer'] == 'RMSprop':
        optimizer = optim.RMSprop(model.parameters(), lr=params['lr'], weight_decay=params['weight_decay'])

    criterion = nn.CrossEntropyLoss()

    num_epochs = 1
    current_best_accuracy = 0.0  # Reset for each hyperparameter set

    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        correct_train = 0
        total_train = 0

        for i, (inputs, labels) in enumerate(train_loader):
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            running_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            total_train += labels.size(0)
            correct_train += (predicted == labels).sum().item()

        train_accuracy = 100 * correct_train / total_train
        print(f"\n Epoch {epoch+1}/{num_epochs}, Loss: {running_loss/len(train_loader)}, Training accuracy: {train_accuracy}")

        model.eval()
        val_loss = 0.0
        correct_val = 0
        total_val = 0

        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                val_loss += loss.item()
                _, predicted = torch.max(outputs.data, 1)
                total_val += labels.size(0)
                correct_val += (predicted == labels).sum().item()

        actual_accuracy = 100 * correct_val / total_val
        print(f'Validation accuracy after epoch {epoch+1}: {actual_accuracy:.2f}%')

        if actual_accuracy > current_best_accuracy:
            current_best_accuracy = actual_accuracy

        if actual_accuracy > best_accuracy:
            best_model = copy.deepcopy(model)
            best_params = params
            best_accuracy = actual_accuracy

    # After all epochs for this hyperparameter set
    key = str(params)
    performance_dict[key] = current_best_accuracy
    print(f"Best validation accuracy for this set of hyperparameters ({params}): {current_best_accuracy:.2f}%")
    print(f"Overall best validation accuracy so far: {best_accuracy:.2f}% with hyperparameters {best_params}")

# After all hyperparameter sets
print("\nOverall best hyperparameters: ", best_params)
print(f"Overall best validation accuracy: {best_accuracy:.2f}%")

print("\nPerformance dictionary:")
print(performance_dict)

# Save the best model
torch.save(best_model, "wiki_TL_resnet_model_hyp.pth")
# Out:
#  Epoch 1/1, Loss: 2.2919089508056643, Training accuracy: 32.02303455182774
# Validation accuracy after epoch 1: 42.34%
# Best validation accuracy for this set of hyperparameters ({'batch_size': 16, 'dropout_rate': 0.1, 'lr': 0.0001, 'optimizer': 'Adam', 'weight_decay': 0}): 42.34%
# Overall best validation accuracy so far: 42.34% with hyperparameters {'batch_size': 16, 'dropout_rate': 0.1, 'lr': 0.0001, 'optimizer': 'Adam', 'weight_decay': 0}
#
#  Epoch 1/1, Loss: 2.286488968372345, Training accuracy: 31.29694541812719
# Validation accuracy after epoch 1: 40.84%
# Best validation accuracy for this set of hyperparameters ({'batch_size': 16, 'dropout_rate': 0.1, 'lr': 0.0001, 'optimizer': 'Adam', 'weight_decay': 0.01}): 40.84%
# Overall best validation accuracy so far: 42.34% with hyperparameters {'batch_size': 16, 'dropout_rate': 0.1, 'lr': 0.0001, 'optimizer': 'Adam', 'weight_decay': 0}
#
#  Epoch 1/1, Loss: 2.3336294145584104, Training accuracy: 29.118678017025537
# Validation accuracy after epoch 1: 41.44%
# Best validation accuracy for this set of hyperparameters ({'batch_size': 16, 'dropout_rate': 0.1, 'lr': 0.0001, 'optimizer': 'RMSprop', 'weight_decay': 0}): 41.44%
# Overall best validation accuracy so far: 42.34% with hyperparameters {'batch_size': 16, 'dropout_rate': 0.1, 'lr': 0.0001, 'optimizer': 'Adam', 'weight_decay': 0}
#
#  Epoch 1/1, Loss: 2.3542478733062744, Training accuracy: 29.31897846770155
# Validation accuracy after epoch 1: 35.74%
# Best validation accuracy for this set of hyperparameters ({'batch_size': 16, 'dropout_rate': 0.1, 'lr': 0.0001, 'optimizer': 'RMSprop', 'weight_decay': 0.01}): 35.74%
# Overall best validation accuracy so far: 42.34% with hyperparameters {'batch_size': 16, 'dropout_rate': 0.1, 'lr': 0.0001, 'optimizer': 'Adam', 'weight_decay': 0}
#
#  Epoch 1/1, Loss: 3.1855381269454957, Training accuracy: 9.514271407110666
# Validation accuracy after epoch 1: 10.01%
# Best validation accuracy for this set of hyperparameters ({'batch_size': 16, 'dropout_rate': 0.1, 'lr': 0.001, 'optimizer': 'Adam', 'weight_decay': 0}): 10.01%
# Overall best validation accuracy so far: 42.34% with hyperparameters {'batch_size': 16, 'dropout_rate': 0.1, 'lr': 0.0001, 'optimizer': 'Adam', 'weight_decay': 0}
#
#  Epoch 1/1, Loss: 3.202336610794067, Training accuracy: 8.212318477716575
# Validation accuracy after epoch 1: 4.30%
# Best validation accuracy for this set of hyperparameters ({'batch_size': 16, 'dropout_rate': 0.1, 'lr': 0.001, 'optimizer': 'Adam', 'weight_decay': 0.01}): 4.30%
# Overall best validation accuracy so far: 42.34% with hyperparameters {'batch_size': 16, 'dropout_rate': 0.1, 'lr': 0.0001, 'optimizer': 'Adam', 'weight_decay': 0}
#
#  Epoch 1/1, Loss: 3.365793848991394, Training accuracy: 4.957436154231347
# Validation accuracy after epoch 1: 10.41%
# Best validation accuracy for this set of hyperparameters ({'batch_size': 16, 'dropout_rate': 0.1, 'lr': 0.001, 'optimizer': 'RMSprop', 'weight_decay': 0}): 10.41%
# Overall best validation accuracy so far: 42.34% with hyperparameters {'batch_size': 16, 'dropout_rate': 0.1, 'lr': 0.0001, 'optimizer': 'Adam', 'weight_decay': 0}
#
#  Epoch 1/1, Loss: 3.4278761014938355, Training accuracy: 4.782173259889834
# Validation accuracy after epoch 1: 5.21%
# Best validation accuracy for this set of hyperparameters ({'batch_size': 16, 'dropout_rate': 0.1, 'lr': 0.001, 'optimizer': 'RMSprop', 'weight_decay': 0.01}): 5.21%
# Overall best validation accuracy so far: 42.34% with hyperparameters {'batch_size': 16, 'dropout_rate': 0.1, 'lr': 0.0001, 'optimizer': 'Adam', 'weight_decay': 0}
#
#  Epoch 1/1, Loss: 2.4140149154663084, Training accuracy: 28.14221331997997
# Validation accuracy after epoch 1: 45.95%
# Best validation accuracy for this set of hyperparameters ({'batch_size': 16, 'dropout_rate': 0.5, 'lr': 0.0001, 'optimizer': 'Adam', 'weight_decay': 0}): 45.95%
# Overall best validation accuracy so far: 45.95% with hyperparameters {'batch_size': 16, 'dropout_rate': 0.5, 'lr': 0.0001, 'optimizer': 'Adam', 'weight_decay': 0}
#
#  Epoch 1/1, Loss: 2.434572847366333, Training accuracy: 27.516274411617427
# Validation accuracy after epoch 1: 40.94%
# Best validation accuracy for this set of hyperparameters ({'batch_size': 16, 'dropout_rate': 0.5, 'lr': 0.0001, 'optimizer': 'Adam', 'weight_decay': 0.01}): 40.94%
# Overall best validation accuracy so far: 45.95% with hyperparameters {'batch_size': 16, 'dropout_rate': 0.5, 'lr': 0.0001, 'optimizer': 'Adam', 'weight_decay': 0}
#
#  Epoch 1/1, Loss: 2.3647685809135437, Training accuracy: 29.31897846770155
# Validation accuracy after epoch 1: 41.74%
# Best validation accuracy for this set of hyperparameters ({'batch_size': 16, 'dropout_rate': 0.5, 'lr': 0.0001, 'optimizer': 'RMSprop', 'weight_decay': 0}): 41.74%
# Overall best validation accuracy so far: 45.95% with hyperparameters {'batch_size': 16, 'dropout_rate': 0.5, 'lr': 0.0001, 'optimizer': 'Adam', 'weight_decay': 0}
#
#  Epoch 1/1, Loss: 2.4379587559700013, Training accuracy: 27.040560841261893
# Validation accuracy after epoch 1: 40.14%
# Best validation accuracy for this set of hyperparameters ({'batch_size': 16, 'dropout_rate': 0.5, 'lr': 0.0001, 'optimizer': 'RMSprop', 'weight_decay': 0.01}): 40.14%
# Overall best validation accuracy so far: 45.95% with hyperparameters {'batch_size': 16, 'dropout_rate': 0.5, 'lr': 0.0001, 'optimizer': 'Adam', 'weight_decay': 0}
#
#  Epoch 1/1, Loss: 3.2120239448547365, Training accuracy: 9.939909864797196
# Validation accuracy after epoch 1: 11.21%
# Best validation accuracy for this set of hyperparameters ({'batch_size': 16, 'dropout_rate': 0.5, 'lr': 0.001, 'optimizer': 'Adam', 'weight_decay': 0}): 11.21%
# Overall best validation accuracy so far: 45.95% with hyperparameters {'batch_size': 16, 'dropout_rate': 0.5, 'lr': 0.0001, 'optimizer': 'Adam', 'weight_decay': 0}
#
#  Epoch 1/1, Loss: 3.3101195011138915, Training accuracy: 6.134201301952929
# Validation accuracy after epoch 1: 7.31%
# Best validation accuracy for this set of hyperparameters ({'batch_size': 16, 'dropout_rate': 0.5, 'lr': 0.001, 'optimizer': 'Adam', 'weight_decay': 0.01}): 7.31%
# Overall best validation accuracy so far: 45.95% with hyperparameters {'batch_size': 16, 'dropout_rate': 0.5, 'lr': 0.0001, 'optimizer': 'Adam', 'weight_decay': 0}
#
#  Epoch 1/1, Loss: 3.3627843313217163, Training accuracy: 5.6084126189283925
# Validation accuracy after epoch 1: 6.31%
# Best validation accuracy for this set of hyperparameters ({'batch_size': 16, 'dropout_rate': 0.5, 'lr': 0.001, 'optimizer': 'RMSprop', 'weight_decay': 0}): 6.31%
# Overall best validation accuracy so far: 45.95% with hyperparameters {'batch_size': 16, 'dropout_rate': 0.5, 'lr': 0.0001, 'optimizer': 'Adam', 'weight_decay': 0}
#
#  Epoch 1/1, Loss: 3.399285497665405, Training accuracy: 4.85728592889334
# Validation accuracy after epoch 1: 3.30%
# Best validation accuracy for this set of hyperparameters ({'batch_size': 16, 'dropout_rate': 0.5, 'lr': 0.001, 'optimizer': 'RMSprop', 'weight_decay': 0.01}): 3.30%
# Overall best validation accuracy so far: 45.95% with hyperparameters {'batch_size': 16, 'dropout_rate': 0.5, 'lr': 0.0001, 'optimizer': 'Adam', 'weight_decay': 0}
#
#  Epoch 1/1, Loss: 2.267435537338257, Training accuracy: 32.62393590385578
# Validation accuracy after epoch 1: 44.24%
# Best validation accuracy for this set of hyperparameters ({'batch_size': 32, 'dropout_rate': 0.1, 'lr': 0.0001, 'optimizer': 'Adam', 'weight_decay': 0}): 44.24%
# Overall best validation accuracy so far: 45.95% with hyperparameters {'batch_size': 16, 'dropout_rate': 0.5, 'lr': 0.0001, 'optimizer': 'Adam', 'weight_decay': 0}
#
#  Epoch 1/1, Loss: 2.288713577270508, Training accuracy: 32.62393590385578
# Validation accuracy after epoch 1: 45.35%
# Best validation accuracy for this set of hyperparameters ({'batch_size': 32, 'dropout_rate': 0.1, 'lr': 0.0001, 'optimizer': 'Adam', 'weight_decay': 0.01}): 45.35%
# Overall best validation accuracy so far: 45.95% with hyperparameters {'batch_size': 16, 'dropout_rate': 0.5, 'lr': 0.0001, 'optimizer': 'Adam', 'weight_decay': 0}
#
#  Epoch 1/1, Loss: 2.187506008148193, Training accuracy: 33.60040060090135
# Validation accuracy after epoch 1: 40.74%
# Best validation accuracy for this set of hyperparameters ({'batch_size': 32, 'dropout_rate': 0.1, 'lr': 0.0001, 'optimizer': 'RMSprop', 'weight_decay': 0}): 40.74%
# Overall best validation accuracy so far: 45.95% with hyperparameters {'batch_size': 16, 'dropout_rate': 0.5, 'lr': 0.0001, 'optimizer': 'Adam', 'weight_decay': 0}
#
#  Epoch 1/1, Loss: 2.2568806896209717, Training accuracy: 31.271907861792688
# Validation accuracy after epoch 1: 38.84%
# Best validation accuracy for this set of hyperparameters ({'batch_size': 32, 'dropout_rate': 0.1, 'lr': 0.0001, 'optimizer': 'RMSprop', 'weight_decay': 0.01}): 38.84%
# Overall best validation accuracy so far: 45.95% with hyperparameters {'batch_size': 16, 'dropout_rate': 0.5, 'lr': 0.0001, 'optimizer': 'Adam', 'weight_decay': 0}
#
#  Epoch 1/1, Loss: 2.84255114364624, Training accuracy: 17.1256885327992
# Validation accuracy after epoch 1: 19.42%
# Best validation accuracy for this set of hyperparameters ({'batch_size': 32, 'dropout_rate': 0.1, 'lr': 0.001, 'optimizer': 'Adam', 'weight_decay': 0}): 19.42%
# Overall best validation accuracy so far: 45.95% with hyperparameters {'batch_size': 16, 'dropout_rate': 0.5, 'lr': 0.0001, 'optimizer': 'Adam', 'weight_decay': 0}
#
#  Epoch 1/1, Loss: 2.9866995162963867, Training accuracy: 14.321482223335002
# Validation accuracy after epoch 1: 14.11%
# Best validation accuracy for this set of hyperparameters ({'batch_size': 32, 'dropout_rate': 0.1, 'lr': 0.001, 'optimizer': 'Adam', 'weight_decay': 0.01}): 14.11%
# Overall best validation accuracy so far: 45.95% with hyperparameters {'batch_size': 16, 'dropout_rate': 0.5, 'lr': 0.0001, 'optimizer': 'Adam', 'weight_decay': 0}
#
#  Epoch 1/1, Loss: 3.410394941329956, Training accuracy: 5.182774161241863
# Validation accuracy after epoch 1: 4.80%
# Best validation accuracy for this set of hyperparameters ({'batch_size': 32, 'dropout_rate': 0.1, 'lr': 0.001, 'optimizer': 'RMSprop', 'weight_decay': 0}): 4.80%
# Overall best validation accuracy so far: 45.95% with hyperparameters {'batch_size': 16, 'dropout_rate': 0.5, 'lr': 0.0001, 'optimizer': 'Adam', 'weight_decay': 0}
#
#  Epoch 1/1, Loss: 3.420192716598511, Training accuracy: 5.182774161241863
# Validation accuracy after epoch 1: 2.70%
# Best validation accuracy for this set of hyperparameters ({'batch_size': 32, 'dropout_rate': 0.1, 'lr': 0.001, 'optimizer': 'RMSprop', 'weight_decay': 0.01}): 2.70%
# Overall best validation accuracy so far: 45.95% with hyperparameters {'batch_size': 16, 'dropout_rate': 0.5, 'lr': 0.0001, 'optimizer': 'Adam', 'weight_decay': 0}
#
#  Epoch 1/1, Loss: 2.4323373050689696, Training accuracy: 28.517776664997495
# Validation accuracy after epoch 1: 45.95%
# Best validation accuracy for this set of hyperparameters ({'batch_size': 32, 'dropout_rate': 0.5, 'lr': 0.0001, 'optimizer': 'Adam', 'weight_decay': 0}): 45.95%
# Overall best validation accuracy so far: 45.95% with hyperparameters {'batch_size': 16, 'dropout_rate': 0.5, 'lr': 0.0001, 'optimizer': 'Adam', 'weight_decay': 0}
#
#  Epoch 1/1, Loss: 2.425049554824829, Training accuracy: 28.14221331997997
# Validation accuracy after epoch 1: 44.54%
# Best validation accuracy for this set of hyperparameters ({'batch_size': 32, 'dropout_rate': 0.5, 'lr': 0.0001, 'optimizer': 'Adam', 'weight_decay': 0.01}): 44.54%
# Overall best validation accuracy so far: 45.95% with hyperparameters {'batch_size': 16, 'dropout_rate': 0.5, 'lr': 0.0001, 'optimizer': 'Adam', 'weight_decay': 0}
#
#  Epoch 1/1, Loss: 2.3056261548995973, Training accuracy: 30.545818728092136
# Validation accuracy after epoch 1: 41.94%
# Best validation accuracy for this set of hyperparameters ({'batch_size': 32, 'dropout_rate': 0.5, 'lr': 0.0001, 'optimizer': 'RMSprop', 'weight_decay': 0}): 41.94%
# Overall best validation accuracy so far: 45.95% with hyperparameters {'batch_size': 16, 'dropout_rate': 0.5, 'lr': 0.0001, 'optimizer': 'Adam', 'weight_decay': 0}
#
#  Epoch 1/1, Loss: 2.331645962715149, Training accuracy: 29.644466700050074
# Validation accuracy after epoch 1: 38.34%
# Best validation accuracy for this set of hyperparameters ({'batch_size': 32, 'dropout_rate': 0.5, 'lr': 0.0001, 'optimizer': 'RMSprop', 'weight_decay': 0.01}): 38.34%
# Overall best validation accuracy so far: 45.95% with hyperparameters {'batch_size': 16, 'dropout_rate': 0.5, 'lr': 0.0001, 'optimizer': 'Adam', 'weight_decay': 0}
#
#  Epoch 1/1, Loss: 2.9630989151000975, Training accuracy: 15.673510265398097
# Validation accuracy after epoch 1: 18.22%
# Best validation accuracy for this set of hyperparameters ({'batch_size': 32, 'dropout_rate': 0.5, 'lr': 0.001, 'optimizer': 'Adam', 'weight_decay': 0}): 18.22%
# Overall best validation accuracy so far: 45.95% with hyperparameters {'batch_size': 16, 'dropout_rate': 0.5, 'lr': 0.0001, 'optimizer': 'Adam', 'weight_decay': 0}
#
#  Epoch 1/1, Loss: 3.063593490600586, Training accuracy: 11.817726589884828
# Validation accuracy after epoch 1: 11.51%
# Best validation accuracy for this set of hyperparameters ({'batch_size': 32, 'dropout_rate': 0.5, 'lr': 0.001, 'optimizer': 'Adam', 'weight_decay': 0.01}): 11.51%
# Overall best validation accuracy so far: 45.95% with hyperparameters {'batch_size': 16, 'dropout_rate': 0.5, 'lr': 0.0001, 'optimizer': 'Adam', 'weight_decay': 0}
#
#  Epoch 1/1, Loss: 3.3797721271514893, Training accuracy: 6.309464196294441
# Validation accuracy after epoch 1: 8.81%
# Best validation accuracy for this set of hyperparameters ({'batch_size': 32, 'dropout_rate': 0.5, 'lr': 0.001, 'optimizer': 'RMSprop', 'weight_decay': 0}): 8.81%
# Overall best validation accuracy so far: 45.95% with hyperparameters {'batch_size': 16, 'dropout_rate': 0.5, 'lr': 0.0001, 'optimizer': 'Adam', 'weight_decay': 0}
#
#  Epoch 1/1, Loss: 3.4414402084350586, Training accuracy: 4.932398597896845
# Validation accuracy after epoch 1: 3.40%
# Best validation accuracy for this set of hyperparameters ({'batch_size': 32, 'dropout_rate': 0.5, 'lr': 0.001, 'optimizer': 'RMSprop', 'weight_decay': 0.01}): 3.40%
# Overall best validation accuracy so far: 45.95% with hyperparameters {'batch_size': 16, 'dropout_rate': 0.5, 'lr': 0.0001, 'optimizer': 'Adam', 'weight_decay': 0}
#
# Overall best hyperparameters:  {'batch_size': 16, 'dropout_rate': 0.5, 'lr': 0.0001, 'optimizer': 'Adam', 'weight_decay': 0}
# Overall best validation accuracy: 45.95%
#
# Performance dictionary:
# {"{'batch_size': 16, 'dropout_rate': 0.1, 'lr': 0.0001, 'optimizer': 'Adam', 'weight_decay': 0}": 42.34234234234234, "{'batch_size': 16, 'dropout_rate': 0.1, 'lr': 0.0001, 'optimizer': 'Adam', 'weight_decay': 0.01}": 40.84084084084084, "{'batch_size': 16, 'dropout_rate': 0.1, 'lr': 0.0001, 'optimizer': 'RMSprop', 'weight_decay': 0}": 41.44144144144144, "{'batch_size': 16, 'dropout_rate': 0.1, 'lr': 0.0001, 'optimizer': 'RMSprop', 'weight_decay': 0.01}": 35.73573573573574, "{'batch_size': 16, 'dropout_rate': 0.1, 'lr': 0.001, 'optimizer': 'Adam', 'weight_decay': 0}": 10.01001001001001, "{'batch_size': 16, 'dropout_rate': 0.1, 'lr': 0.001, 'optimizer': 'Adam', 'weight_decay': 0.01}": 4.3043043043043046, "{'batch_size': 16, 'dropout_rate': 0.1, 'lr': 0.001, 'optimizer': 'RMSprop', 'weight_decay': 0}": 10.41041041041041, "{'batch_size': 16, 'dropout_rate': 0.1, 'lr': 0.001, 'optimizer': 'RMSprop', 'weight_decay': 0.01}": 5.205205205205205, "{'batch_size': 16, 'dropout_rate': 0.5, 'lr': 0.0001, 'optimizer': 'Adam', 'weight_decay': 0}": 45.945945945945944, "{'batch_size': 16, 'dropout_rate': 0.5, 'lr': 0.0001, 'optimizer': 'Adam', 'weight_decay': 0.01}": 40.94094094094094, "{'batch_size': 16, 'dropout_rate': 0.5, 'lr': 0.0001, 'optimizer': 'RMSprop', 'weight_decay': 0}": 41.74174174174174, "{'batch_size': 16, 'dropout_rate': 0.5, 'lr': 0.0001, 'optimizer': 'RMSprop', 'weight_decay': 0.01}": 40.14014014014014, "{'batch_size': 16, 'dropout_rate': 0.5, 'lr': 0.001, 'optimizer': 'Adam', 'weight_decay': 0}": 11.21121121121121, "{'batch_size': 16, 'dropout_rate': 0.5, 'lr': 0.001, 'optimizer': 'Adam', 'weight_decay': 0.01}": 7.307307307307307, "{'batch_size': 16, 'dropout_rate': 0.5, 'lr': 0.001, 'optimizer': 'RMSprop', 'weight_decay': 0}": 6.306306306306307, "{'batch_size': 16, 'dropout_rate': 0.5, 'lr': 0.001, 'optimizer': 'RMSprop', 'weight_decay': 0.01}": 3.3033033033033035, "{'batch_size': 32, 'dropout_rate': 0.1, 'lr': 0.0001, 'optimizer': 'Adam', 'weight_decay': 0}": 44.24424424424424, "{'batch_size': 32, 'dropout_rate': 0.1, 'lr': 0.0001, 'optimizer': 'Adam', 'weight_decay': 0.01}": 45.34534534534534, "{'batch_size': 32, 'dropout_rate': 0.1, 'lr': 0.0001, 'optimizer': 'RMSprop', 'weight_decay': 0}": 40.74074074074074, "{'batch_size': 32, 'dropout_rate': 0.1, 'lr': 0.0001, 'optimizer': 'RMSprop', 'weight_decay': 0.01}": 38.83883883883884, "{'batch_size': 32, 'dropout_rate': 0.1, 'lr': 0.001, 'optimizer': 'Adam', 'weight_decay': 0}": 19.41941941941942, "{'batch_size': 32, 'dropout_rate': 0.1, 'lr': 0.001, 'optimizer': 'Adam', 'weight_decay': 0.01}": 14.114114114114114, "{'batch_size': 32, 'dropout_rate': 0.1, 'lr': 0.001, 'optimizer': 'RMSprop', 'weight_decay': 0}": 4.804804804804805, "{'batch_size': 32, 'dropout_rate': 0.1, 'lr': 0.001, 'optimizer': 'RMSprop', 'weight_decay': 0.01}": 2.7027027027027026, "{'batch_size': 32, 'dropout_rate': 0.5, 'lr': 0.0001, 'optimizer': 'Adam', 'weight_decay': 0}": 45.945945945945944, "{'batch_size': 32, 'dropout_rate': 0.5, 'lr': 0.0001, 'optimizer': 'Adam', 'weight_decay': 0.01}": 44.54454454454454, "{'batch_size': 32, 'dropout_rate': 0.5, 'lr': 0.0001, 'optimizer': 'RMSprop', 'weight_decay': 0}": 41.94194194194194, "{'batch_size': 32, 'dropout_rate': 0.5, 'lr': 0.0001, 'optimizer': 'RMSprop', 'weight_decay': 0.01}": 38.33833833833834, "{'batch_size': 32, 'dropout_rate': 0.5, 'lr': 0.001, 'optimizer': 'Adam', 'weight_decay': 0}": 18.21821821821822, "{'batch_size': 32, 'dropout_rate': 0.5, 'lr': 0.001, 'optimizer': 'Adam', 'weight_decay': 0.01}": 11.511511511511511, "{'batch_size': 32, 'dropout_rate': 0.5, 'lr': 0.001, 'optimizer': 'RMSprop', 'weight_decay': 0}": 8.80880880880881, "{'batch_size': 32, 'dropout_rate': 0.5, 'lr': 0.001, 'optimizer': 'RMSprop', 'weight_decay': 0.01}": 3.4034034034034035}

# %%
# performance_dict
import pandas as pd
perf_summary = pd.DataFrame.from_dict(performance_dict, orient ='index')
perf_summary.reset_index(inplace = True)
perf_summary.rename(columns = {'index':'parameters',0:'accuracy'}, inplace = True)
perf_summary.sort_values(by = 'accuracy')
perf_summary.to_csv("performance_summary.csv", index = False)

# %%
# torch.save(model, "wiki_TL_resnet_model.pth")
# print(f"Best model saved with accuracy: {best_accuracy:.2f}%")

# %%
# Calculate the most frequent label in the training set
label_counts = Counter([label for _, label in train_dataset])
most_common_label, frequency = label_counts.most_common(1)[0]

# Calculate the expected accuracy if no model (always predicting the most frequent label)
baseline_accuracy = (frequency / len(train_dataset)) * 100
print(f"Expected accuracy if no model: {baseline_accuracy:.2f}%")
# Out:
# Expected accuracy if no model: 4.66%
